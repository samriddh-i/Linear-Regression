# %%
# libraries import karte hai 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# data set import karte hai 
dataset = pd.read_csv('Salary_Data.csv')

# %%
# dependedn and independed banayenge
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(x)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
print(y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
# train and test me divide karenge 
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test =  train_test_split(x,y, test_size=0.2, random_state = 0)

# %%
# model banate hai Linear Regression
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_prediction = regressor.predict(x_test)

# %%
# visualaise karte hai training wala
plt.scatter(x_train,y_train, color = 'green')
plt.plot(x_train , regressor.predict(x_train), color = 'blue')
plt.title('salary vs experience')
plt.xlabel('experience')
plt.ylabel('salary')
plt.show()

# %%
# visualaise karte hai test wala
plt.scatter(x_test,y_test, color = 'green')
plt.plot(x_train , regressor.predict(x_train), color = 'blue')
plt.title('salary vs experience')
plt.xlabel('experience')
plt.xlabel('salary')
plt.show()

# %%
print(regressor.predict([[7.9]]))
# Out:
# [100349.44265179]
